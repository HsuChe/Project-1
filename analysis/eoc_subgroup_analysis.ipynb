# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
from analysis import analysis

# %%
# load dropout data
csvpath = '../merge_ready_data/eoc_type_clean.csv'
csvpath_dep = '../merge_ready_data/dependent_variable_clean.csv'
df = pd.read_csv(csvpath)
dep_var_df = pd.read_csv(csvpath_dep)

# %% [markdown]
# # Analyze Dropout Rates

# %%
merged_df = pd.merge(dep_var_df, df, on="School District Code", how="inner")
merged_df = merged_df.dropna()
merged_df['PCT_analysis'] = merged_df['BEGIN_PCT'] + merged_df['BEGIN_PCT']
merged_df = merged_df.replace('Economics/Business/Free Enterprise','Economics & Business & Free Enterprise')
merged_df.columns
# Out:
# Index(['School Year', 'School District Code', 'School District Name',
#        'School Code', 'School Name', 'Graduates', 'Postsecondary Institution',
#        'Percent', 'Unnamed: 0', 'TEST_CMPNT_TYP_NM', 'NUM_TESTED_CNT',
#        'BEGIN_CNT', 'DEVELOPING_CNT', 'PROFICIENT_CNT', 'DISTINGUISHED_CNT',
#        'BEGIN_PCT', 'DEVELOPING_PCT', 'PROFICIENT_PCT', 'DISTINGUISHED_PCT',
#        'PCT_analysis'],
#       dtype='object')

# %%
# merged_academic = merged DataFrame
# description = label for the independent variable
# selection_column = column where the labels of the independent variables are
# selection_column = values for the independent variable

merged_academic = merged_df
selection_column = 'TEST_CMPNT_TYP_NM'
ind_var_label = 'PCT_analysis'

# %%
analysis(merged_academic,selection_column,ind_var_label)
# Out:
# regression function = f(x) = x*-0.11 + 66.72
# p-value: 0.0017624595514645625
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-1b714fdd5600> in <module>
# ----> 1 analysis(merged_academic,selection_column,ind_var_label)
#
# c:\Users\hsueh\OneDrive\Desktop\Project 1\Project-1\analysis\analysis.py in analysis(df, ind_label, ind_value)
#      48         x_values = ind_df[ind_value]
#      49         y_values = ind_df['Percent']
# ---> 50         (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
#      51         regress_values = x_values * slope + intercept
#      52         print(f'regression function = f(x) = x*{slope.round(2)} + {intercept.round(2)}')
#
# ~\Conda\envs\PythonEnv3.9\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     134
#     135     if x.size == 0 or y.size == 0:
# --> 136         raise ValueError("Inputs must not be empty.")
#     137
#     138     n = len(x)
#
# ValueError: Inputs must not be empty.
