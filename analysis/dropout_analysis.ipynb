# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
from analysis import analysis

# %%
# load dropout data
csvpath = '../merge_ready_data/dropout_clean.csv'
csvpath_dep = '../merge_ready_data/dependent_variable_clean.csv'
df = pd.read_csv(csvpath)
dep_var_df = pd.read_csv(csvpath_dep)

# %% [markdown]
# # Analyze Dropout Rates

# %%
merged_df = pd.merge(dep_var_df, df, on="School District Code", how="inner")
merged_df = merged_df.dropna()
merged_df.columns
# Out:
# Index(['School Year', 'School District Code', 'School District Name',
#        'School Code', 'School Name', 'Graduates', 'Postsecondary Institution',
#        'Percent', 'Unnamed: 0', 'LABEL_LVL_1_DESC', 'PROGRAM_TOTAL',
#        'PROGRAM_PERCENT'],
#       dtype='object')

# %%
# merged_academic = merged DataFrame
# description = label for the independent variable
# selection_column = column where the labels of the independent variables are
# selection_column = values for the independent variable

merged_academic = merged_df
selection_column = 'LABEL_LVL_1_DESC'
ind_var_label = 'PROGRAM_PERCENT'

# %%
analysis(merged_academic,selection_column,ind_var_label)
# Out:
# Printing 7-12 Drop Outs -ALL Students data
# regression function = f(x) = x*-0.94 + 65.5
# p-value: 0.00549763620928099
# std error: 0.3331847066574471
# Printing 7-12 Drop Outs -Economically Disadvantaged data
# regression function = f(x) = x*0.14 + 62.18
# p-value: 0.7358611487659321
# std error: 0.4286402285804101
# Printing 7-12 Drop Outs -Female data
# regression function = f(x) = x*-0.65 + 64.67
# p-value: 0.12699571824918268
# std error: 0.42205514553079554
# Printing 7-12 Drop Outs -Male data
# regression function = f(x) = x*-0.41 + 63.88
# p-value: 0.24121825854501522
# std error: 0.3467036289875065
# Printing 7-12 Drop Outs -Students Without Disability data
# regression function = f(x) = x*-0.75 + 64.69
# p-value: 0.03067342954703592
# std error: 0.34534593490818893
# Printing 7-12 Drop Outs -White data
# regression function = f(x) = x*-1.18 + 65.64
# p-value: 0.011675145916442795
# std error: 0.4608420758934271
# Printing 7-12 Drop Outs -Black data
# regression function = f(x) = x*-0.36 + 65.89
# p-value: 0.3650777128495204
# std error: 0.39956508175586936
# Printing 7-12 Drop Outs -Hispanic data
# regression function = f(x) = x*-0.05 + 67.27
# p-value: 0.8976126872453021
# std error: 0.4111835186529835
# Printing 7-12 Drop Outs -Limited English Proficient data
# regression function = f(x) = x*-0.62 + 71.55
# p-value: 0.11579581918338523
# std error: 0.37561269226905275
# Printing 7-12 Drop Outs -Not Economically Disadvantaged data
# regression function = f(x) = x*-0.29 + 66.26
# p-value: 0.4458358839750165
# std error: 0.38080331051974353
# Printing 7-12 Drop Outs -Students With Disability data
# regression function = f(x) = x*-0.25 + 65.71
# p-value: 0.49372738659435855
# std error: 0.35563663206150214
# Printing 7-12 Drop Outs -Multi-Racial data
# regression function = f(x) = x*-2.1 + 74.03
# p-value: 0.2154302038560583
# std error: 1.6080480160107047
# Printing 7-12 Drop Outs -Asian/Pacific Islander data
# regression function = f(x) = x*-1.62 + 73.69
# p-value: 0.4633029893684006
# std error: 1.934566726740488
