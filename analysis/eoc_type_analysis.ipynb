# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
from analysis import bar_graph

# %%
# load dropout data
csvpath = '../merge_ready_data/eoc_subgroup_clean.csv'
csvpath_dep = '../merge_ready_data/dependent_variable_clean.csv'
df = pd.read_csv(csvpath)
dep_var_df = pd.read_csv(csvpath_dep)

# %% [markdown]
# # Analyze Dropout Rates

# %%
merged_df = pd.merge(dep_var_df, df, on="School District Code", how="inner")
merged_df = merged_df.dropna()
merged_df['PCT_analysis'] = merged_df['BEGIN_PCT'] + merged_df['BEGIN_PCT']
merged_df
# Out:
#         School Year  School District Code            School District Name  \
# 0              2017                   601                  Appling County
# 1              2017                   601                  Appling County
# 2              2017                   601                  Appling County
# 3              2017                   601                  Appling County
# 4              2017                   601                  Appling County
# ...             ...                   ...                             ...
# 108168         2017                   891  Department of Juvenile Justice
# 108169         2017                   891  Department of Juvenile Justice
# 108170         2017                   891  Department of Juvenile Justice
# 108171         2017                   891  Department of Juvenile Justice
# 108172         2017                   891  Department of Juvenile Justice
#
#        School Code  School Name  Graduates  Postsecondary Institution  \
# 0              ALL  All Schools      198.0                      118.0
# 1              ALL  All Schools      198.0                      118.0
# 2              ALL  All Schools      198.0                      118.0
# 3              ALL  All Schools      198.0                      118.0
# 4              ALL  All Schools      198.0                      118.0
# ...            ...          ...        ...                        ...
# 108168         ALL  All Schools       20.0                       10.0
# 108169         ALL  All Schools       20.0                       10.0
# 108170         ALL  All Schools       20.0                       10.0
# 108171         ALL  All Schools       20.0                       10.0
# 108172         ALL  All Schools       20.0                       10.0
#
#         Percent  Unnamed: 0                   SUBGROUP_NAME BEGIN_CNT  \
# 0          59.6           0                    All Students        41
# 1          59.6           1                    All Students        36
# 2          59.6           2                    All Students       TFS
# 3          59.6           3                    All Students        10
# 4          59.6           4                            Male        29
# ...         ...         ...                             ...       ...
# 108168     50.0      111142       Black or African American        13
# 108169     50.0      111143   Students without Disabilities        11
# 108170     50.0      111144  Not Limited English Proficient        15
# 108171     50.0      111145  Not Economically Disadvantaged        15
# 108172     50.0      111146                     Non-Migrant        15
#
#        DEVELOPING_CNT PROFICIENT_CNT DISTINGUISHED_CNT  BEGIN_PCT  \
# 0                  87             96                26       16.4
# 1                  84             97                22       15.1
# 2                  16             32                13       12.9
# 3                 TFS            TFS               TFS       76.9
# 4                  51             45               TFS       22.0
# ...               ...            ...               ...        ...
# 108168            TFS            TFS               TFS       92.9
# 108169            TFS            TFS               TFS       64.7
# 108170            TFS            TFS               TFS       71.4
# 108171            TFS            TFS               TFS       71.4
# 108172            TFS            TFS               TFS       71.4
#
#         DEVELOPING_PCT  PROFICIENT_PCT  DISTINGUISHED_PCT  PCT_analysis
# 0                 34.8            38.4               10.4          32.8
# 1                 35.1            40.6                9.2          30.2
# 2                 22.9            45.7               18.6          25.8
# 3                 15.4             7.7                0.0         153.8
# 4                 38.6            34.1                5.3          44.0
# ...                ...             ...                ...           ...
# 108168             7.1             0.0                0.0         185.8
# 108169            23.5            11.8                0.0         129.4
# 108170            19.0             9.5                0.0         142.8
# 108171            19.0             9.5                0.0         142.8
# 108172            19.0             9.5                0.0         142.8
#
# [108173 rows x 19 columns]

# %%
# merged_academic = merged DataFrame
# description = label for the independent variable
# selection_column = column where the labels of the independent variables are
# selection_column = values for the independent variable

merged_academic = merged_df
selection_column = 'SUBGROUP_NAME'
ind_var_label = 'PCT_analysis'

# %%
bar_graph(merged_academic,selection_column,ind_var_label)
# Out:
# C:\Users\hsueh\Conda\envs\PythonEnv3.9\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\hsueh\Conda\envs\PythonEnv3.9\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Conda\envs\PythonEnv3.9\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Percent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-d3999fe13f34> in <module>
# ----> 1 bar_graph(merged_academic,selection_column,ind_var_label)
#
# c:\Users\hsueh\OneDrive\Desktop\Project 1 final\analysis\analysis.py in bar_graph(merged_academic, selection_column, indepent_var_label)
#      16         instruction_df = instruction_df.loc[(instruction_df[f'{description}_zscore']<3) & (instruction_df[f'{description}_zscore']>-3)]
#      17         x_values = instruction_df[indepent_var_label]
# ---> 18         y_values = instruction_df['Percent']
#      19         plt.scatter(x_values,y_values)
#      20         (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
#
# ~\Conda\envs\PythonEnv3.9\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\Conda\envs\PythonEnv3.9\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Percent'
