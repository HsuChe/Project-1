# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
from analysis import analysis

# %%
# load dropout data
csvpath = '../merge_ready_data/eoc_subgroup_clean.csv'
csvpath_dep = '../merge_ready_data/dependent_variable_clean.csv'
df = pd.read_csv(csvpath)
dep_var_df = pd.read_csv(csvpath_dep)

# %% [markdown]
# # Analyze Dropout Rates

# %%
merged_df = pd.merge(dep_var_df, df, on="School District Code", how="inner")
merged_df = merged_df.dropna()
merged_df['PCT_analysis'] = merged_df['BEGIN_PCT'] + merged_df['BEGIN_PCT']
# merged_df = merged_df.replace('Grad Rate -Asian/Pacific Islander','Grad Rate -Asian or Pacific Islander')
# merged_df = merged_df.replace('Grad Rate -American Indian/Alaskan','Grad Rate -American Indian or Alaskan')
merged_df['SUBGROUP_NAME'].unique()
# Out:
# array(['All Students', 'Male', 'Female', 'Black or African American',
#        'White', 'Hispanic', 'Students with Disabilities',
#        'Students without Disabilities', 'Not Limited English Proficient',
#        'Economically Disadvantaged', 'Migrant', 'Non-Migrant',
#        'Not Economically Disadvantaged', 'Asian', 'Two or More Races',
#        'Limited English Proficient', 'American Indian or Alaskan Native',
#        'Native Hawaiian or Other Pacific Islander'], dtype=object)

# %%
# merged_academic = merged DataFrame
# description = label for the independent variable
# selection_column = column where the labels of the independent variables are
# selection_column = values for the independent variable

merged_academic = merged_df
selection_column = 'SUBGROUP_NAME'
ind_var_label = 'PCT_analysis'

# %%
analysis(merged_academic,selection_column,ind_var_label)
# Out:
# regression function = f(x) = x*-0.09 + 68.28
# p-value: 0.0035822215514254912
# regression function = f(x) = x*-0.12 + 73.01
# p-value: 1.4345491347777009e-05
# regression function = f(x) = x*-0.06 + 66.63
# p-value: 0.0753779493847879
# regression function = f(x) = x*-0.09 + 67.66
# p-value: 0.0032931662645113388
# regression function = f(x) = x*-0.1 + 68.11
# p-value: 0.013704968493515116
# regression function = f(x) = x*-0.09 + 68.56
# p-value: 0.0015515323202673664
# regression function = f(x) = x*0.06 + 54.63
# p-value: 0.5750279210107487
# regression function = f(x) = x*-0.09 + 68.27
# p-value: 0.003533445811396688
# regression function = f(x) = x*-0.09 + 68.09
# p-value: 0.00380159743884104
# regression function = f(x) = x*-0.09 + 74.18
# p-value: 0.00028894867553217607
# regression function = f(x) = x*-0.07 + 66.71
# p-value: 0.010796717197086404
# regression function = f(x) = x*-0.23 + 71.36
# p-value: 5.1611487471509444e-08
# regression function = f(x) = x*-0.18 + 70.38
# p-value: 0.014295335201037367
# regression function = f(x) = x*-0.22 + 71.74
# p-value: 0.011755487768969723
# regression function = f(x) = x*-0.15 + 84.8
# p-value: 0.00016606778404995004
# regression function = f(x) = x*-0.23 + 73.12
# p-value: 5.9980899850536524e-05
# regression function = f(x) = x*-0.48 + 89.83
# p-value: 0.016454945616405148
# regression function = f(x) = x*-0.21 + 82.44
# p-value: 0.0
